# %% [markdown]
# # Assignment 5, Problem 1
#
# This is the starter code for Assignment 5, Problem 1.
#
# In this assignment, you will solve increasingly challenging tasks from the [Minigrid benchmark](https://minigrid.farama.org/).

# %%
import gymnasium as gym
import minigrid
import numpy as np

np.set_printoptions(formatter={'float': lambda x: "{0:0.2f}".format(x)})

# %%
def compute_score(task, policy):
  num_episodes = 10
  cur_episode  = 0

  seed_by_episode = [42, 34, 50, 1, 9, 7, 43, 56, 90, 11]
  score_by_episode = np.zeros(num_episodes)

  while cur_episode < num_episodes:

    cumulative_reward = 0
    cur_seed = seed_by_episode[cur_episode]

    observation, info = task.reset(seed=cur_seed)
    done = False

    while not done:
      action = policy(observation)
      observation, reward, terminated, truncated, info = task.step(action)
      cumulative_reward += reward

      if terminated or truncated:
        done = True
        score_by_episode[cur_episode] = cumulative_reward
        cur_episode += 1

  score_mean = round(score_by_episode.mean(), 3)
  score_std  = round(score_by_episode.std(), 3)
  score_best = round(score_by_episode.max(), 3)

  print(f"Best score: {score_best}")
  print(f"Average score: {score_mean, score_std}")

  return score_by_episode

# %% [markdown]
# ## Problem 1
# Solve the [Minigrid Unlock](https://minigrid.farama.org/environments/minigrid/UnlockEnv/) task.
#
# This problem is worth 5 points.
#
# ![](https://minigrid.farama.org/_images/UnlockEnv.gif)

# %%
first_task = gym.make("MiniGrid-Unlock-v0")

# %%
######## PUT YOUR CODE HERE ########
# Train an agent to solve the task
import torch
from torch import nn

from stable_baselines3 import PPO
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class MinigridFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.Space, features_dim: int = 512) -> None:
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 16, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(16, 32, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(32, 64, (2, 2)),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))


policy_kwargs = dict(
    features_extractor_class=MinigridFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=128),
)

env = minigrid.wrappers.ImgObsWrapper(first_task)

model = PPO("CnnPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(5e5)
######## PUT YOUR CODE HERE ########
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 288      |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 2776     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009298239 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -5.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 1.78e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1107        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010906992 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -4.82       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.03        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00876    |
# |    value_loss           | 2.09e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011369674 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -6.4        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0371     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00992    |
# |    value_loss           | 2.56e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 0.0227      |
# | time/                   |             |
# |    fps                  | 1014        |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014915838 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | -3.31       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00452     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 2.81e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | 0.0283      |
# | time/                   |             |
# |    fps                  | 949         |
# |    iterations           | 6           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013773182 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | -0.0249     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0088     |
# |    value_loss           | 0.0028      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | 0.0376      |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 7           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008542605 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | -0.181      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0177     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00581    |
# |    value_loss           | 0.000722    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | 0.033       |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 8           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011238361 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -0.0244     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0021      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00867    |
# |    value_loss           | 0.00206     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | 0.0295      |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 9           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.022896854 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -8.29       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000688   |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 7.57e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | 0.0306      |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 10          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010220816 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -4.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00734    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 3.55e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 281         |
# |    ep_rew_mean          | 0.0279      |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 11          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009714844 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -0.0145     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00673    |
# |    value_loss           | 0.000433    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 281          |
# |    ep_rew_mean          | 0.0256       |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 12           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0146695245 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | -6.04        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0218      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0152      |
# |    value_loss           | 3.34e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 0.0237      |
# | time/                   |             |
# |    fps                  | 842         |
# |    iterations           | 13          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011289373 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -4.33       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0611     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 2.15e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 0.0223      |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 14          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010620569 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -3.87       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00273    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 2.55e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 280          |
# |    ep_rew_mean          | 0.0317       |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 15           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0144877415 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | -3.57        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0148      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 2.67e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | 0.0376      |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 16          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010977536 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.00984     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00948     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 0.00224     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | 0.0376      |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 17          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018972434 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -0.0485     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00694    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | 0.0376      |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 18          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014355777 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -6.81       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00714    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 3.73e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 281         |
# |    ep_rew_mean          | 0.0254      |
# | time/                   |             |
# |    fps                  | 827         |
# |    iterations           | 19          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014745373 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -2.34       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0401     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 1.61e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 0.0234      |
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 20          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012722429 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -4.44       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0139     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00992    |
# |    value_loss           | 1.54e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 0.0272      |
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 21          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009746248 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.0418      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.014       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 0.000991    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 0.0272      |
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 22          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011950327 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.0515      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0284     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00908    |
# |    value_loss           | 0.000266    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | 0.0328      |
# | time/                   |             |
# |    fps                  | 835         |
# |    iterations           | 23          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015124147 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | -2.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 2.06e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | 0.0407      |
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 24          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009365567 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.0675      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00683    |
# |    value_loss           | 0.00134     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 276         |
# |    ep_rew_mean          | 0.0506      |
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 25          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011074359 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.0646      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00633     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.0018      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 0.0524      |
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 26          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009488483 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.0454      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0148      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 0.00223     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | 0.0599      |
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 27          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013555516 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | -0.343      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0337     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 0.000156    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 0.053       |
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 28          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008671364 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.0288      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00756    |
# |    value_loss           | 0.00228     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 276         |
# |    ep_rew_mean          | 0.0505      |
# | time/                   |             |
# |    fps                  | 846         |
# |    iterations           | 29          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.016421916 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | -1.27       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0433     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 4e-05       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 0.0514      |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 30          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012810642 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0144      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 3.15e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 275        |
# |    ep_rew_mean          | 0.0546     |
# | time/                   |            |
# |    fps                  | 848        |
# |    iterations           | 31         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.01123892 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | 0.0151     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0056    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.01      |
# |    value_loss           | 0.00193    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | 0.0599      |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 32          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.018173777 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | -0.497      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0218     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 0.000427    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 274        |
# |    ep_rew_mean          | 0.0593     |
# | time/                   |            |
# |    fps                  | 851        |
# |    iterations           | 33         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01740852 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.0257     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0184    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00982   |
# |    value_loss           | 0.00111    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | 0.0621      |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 34          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.013895186 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.0378      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0159     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00976    |
# |    value_loss           | 0.00076     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 270          |
# |    ep_rew_mean          | 0.071        |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 35           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0137462225 |
# |    clip_fraction        | 0.148        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.0334       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00107     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00967     |
# |    value_loss           | 0.00104      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | 0.0654      |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 36          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012653869 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.0971      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00426    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 0.00266     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 271         |
# |    ep_rew_mean          | 0.0663      |
# | time/                   |             |
# |    fps                  | 856         |
# |    iterations           | 37          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.028707873 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0505     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0549     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 9.66e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 271         |
# |    ep_rew_mean          | 0.0648      |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 38          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013252055 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0712     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00868     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00818    |
# |    value_loss           | 0.00235     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 269          |
# |    ep_rew_mean          | 0.0713       |
# | time/                   |              |
# |    fps                  | 858          |
# |    iterations           | 39           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0125550395 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.0333      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0373      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00836     |
# |    value_loss           | 0.00131      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 267         |
# |    ep_rew_mean          | 0.0789      |
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 40          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011551566 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.0365      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00622     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00831    |
# |    value_loss           | 0.00322     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 267        |
# |    ep_rew_mean          | 0.0789     |
# | time/                   |            |
# |    fps                  | 860        |
# |    iterations           | 41         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01228698 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.0219     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0163    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00837   |
# |    value_loss           | 0.00444    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 265         |
# |    ep_rew_mean          | 0.0888      |
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 42          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011072437 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0244      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.000107    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 267         |
# |    ep_rew_mean          | 0.082       |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 43          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011561876 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0193      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00748    |
# |    value_loss           | 0.00156     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 267         |
# |    ep_rew_mean          | 0.0812      |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 44          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.022952497 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -1.15       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0638     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 0.00018     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | 0.0894      |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 45          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.015298792 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0424      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00776     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.000206    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 262        |
# |    ep_rew_mean          | 0.0981     |
# | time/                   |            |
# |    fps                  | 860        |
# |    iterations           | 46         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.02350844 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.0301     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0279    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 0.00385    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 262         |
# |    ep_rew_mean          | 0.0978      |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 47          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011635221 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.0598      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0252      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00625    |
# |    value_loss           | 0.00447     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | 0.105       |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 48          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012832575 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -0.762      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0554     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.00026     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 0.148       |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 49          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.012117021 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.00276    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0212     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00699    |
# |    value_loss           | 0.00396     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 0.163       |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 50          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.012795589 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00532    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00765     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 246        |
# |    ep_rew_mean          | 0.161      |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 51         |
# |    time_elapsed         | 122        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.02068019 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.0201     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0274     |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0109    |
# |    value_loss           | 0.00254    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 237         |
# |    ep_rew_mean          | 0.197       |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 52          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010376891 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.0644      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00523    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00686    |
# |    value_loss           | 0.00201     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 0.245       |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 53          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010853794 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.0276      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00443     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.00965     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 0.311       |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 54          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.009863652 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0165      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00955    |
# |    value_loss           | 0.00886     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | 0.333        |
# | time/                   |              |
# |    fps                  | 850          |
# |    iterations           | 55           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0126011195 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0112       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.028       |
# |    n_updates            | 540          |
# ...
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0247     |
# |    n_updates            | 2260        |
# |    policy_gradient_loss | -0.00668    |
# |    value_loss           | 0.000472    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.2       |
# |    ep_rew_mean          | 0.968      |
# | time/                   |            |
# |    fps                  | 851        |
# |    iterations           | 228        |
# |    time_elapsed         | 548        |
# |    total_timesteps      | 466944     |
# | train/                  |            |
# |    approx_kl            | 0.02011995 |
# |    clip_fraction        | 0.0825     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0992    |
# |    explained_variance   | 0.721      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00936   |
# |    n_updates            | 2270       |
# |    policy_gradient_loss | -0.00896   |
# |    value_loss           | 0.000328   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.3        |
# |    ep_rew_mean          | 0.965       |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 229         |
# |    time_elapsed         | 550         |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.029089883 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0117      |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 0.000374    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 230         |
# |    time_elapsed         | 553         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.046727616 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.153      |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.031      |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 0.000479    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.5        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 231         |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.036955837 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.14       |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0108     |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 0.00044     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 232         |
# |    time_elapsed         | 557         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.038517162 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.123      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.000327    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 233         |
# |    time_elapsed         | 559         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.036169883 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0323     |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 0.000436    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.75       |
# |    ep_rew_mean          | 0.97       |
# | time/                   |            |
# |    fps                  | 852        |
# |    iterations           | 234        |
# |    time_elapsed         | 562        |
# |    total_timesteps      | 479232     |
# | train/                  |            |
# |    approx_kl            | 0.04324396 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.157     |
# |    explained_variance   | 0.606      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.058     |
# |    n_updates            | 2330       |
# |    policy_gradient_loss | -0.0575    |
# |    value_loss           | 0.000579   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.5        |
# |    ep_rew_mean          | 0.964       |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 235         |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.021083111 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0724     |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00709    |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00761    |
# |    value_loss           | 0.00285     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.3       |
# |    ep_rew_mean          | 0.968      |
# | time/                   |            |
# |    fps                  | 852        |
# |    iterations           | 236        |
# |    time_elapsed         | 566        |
# |    total_timesteps      | 483328     |
# | train/                  |            |
# |    approx_kl            | 0.04050409 |
# |    clip_fraction        | 0.0843     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.107     |
# |    explained_variance   | 0.568      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0248    |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | 0.00982    |
# |    value_loss           | 0.00079    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.6       |
# |    ep_rew_mean          | 0.967      |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 237        |
# |    time_elapsed         | 568        |
# |    total_timesteps      | 485376     |
# | train/                  |            |
# |    approx_kl            | 0.03264408 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0986    |
# |    explained_variance   | 0.687      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0231    |
# |    n_updates            | 2360       |
# |    policy_gradient_loss | -0.00856   |
# |    value_loss           | 0.000287   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.4       |
# |    ep_rew_mean          | 0.968      |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 238        |
# |    time_elapsed         | 571        |
# |    total_timesteps      | 487424     |
# | train/                  |            |
# |    approx_kl            | 0.02014962 |
# |    clip_fraction        | 0.0686     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.103     |
# |    explained_variance   | 0.714      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0401    |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.0115    |
# |    value_loss           | 0.000306   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.2       |
# |    ep_rew_mean          | 0.968      |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 239        |
# |    time_elapsed         | 573        |
# |    total_timesteps      | 489472     |
# | train/                  |            |
# |    approx_kl            | 0.07216207 |
# |    clip_fraction        | 0.0988     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0771    |
# |    explained_variance   | 0.787      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0155    |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.0147    |
# |    value_loss           | 0.000273   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.3        |
# |    ep_rew_mean          | 0.965       |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 240         |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.037794393 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0859     |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00908    |
# |    value_loss           | 0.000358    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.4       |
# |    ep_rew_mean          | 0.967      |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 241        |
# |    time_elapsed         | 578        |
# |    total_timesteps      | 493568     |
# | train/                  |            |
# |    approx_kl            | 0.05727011 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.129     |
# |    explained_variance   | 0.505      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0319    |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | -0.0142    |
# |    value_loss           | 0.000854   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.5        |
# |    ep_rew_mean          | 0.964       |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 242         |
# |    time_elapsed         | 580         |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.054801777 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.077      |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0285     |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 0.000352    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.8       |
# |    ep_rew_mean          | 0.963      |
# | time/                   |            |
# |    fps                  | 854        |
# |    iterations           | 243        |
# |    time_elapsed         | 582        |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.10475299 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.181     |
# |    explained_variance   | 0.383      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0436    |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.014     |
# |    value_loss           | 0.00133    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 244         |
# |    time_elapsed         | 584         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.055513564 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.125      |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0294     |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.00101     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.83        |
# |    ep_rew_mean          | 0.969       |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 245         |
# |    time_elapsed         | 587         |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.046284527 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0802     |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.000466    |
# -----------------------------------------

# %%
######## ALSO PUTTING CODE HERE ########
model.save("models/q1.pth")
first_model = PPO.load("models/q1.pth")
######## ALSO PUTTING CODE HERE ########

# %%
def first_policy(observation):
  ######## PUT YOUR CODE HERE ########
  action = first_model.predict(observation["image"])[0]
  ######## PUT YOUR CODE HERE ########
  return action

# %%
compute_score(task=first_task, policy=first_policy)
# Out:
# Best score: 0.981
# Average score: (0.962, 0.016)
# array([0.97, 0.96, 0.98, 0.96, 0.97, 0.93, 0.98, 0.93, 0.96, 0.97])
